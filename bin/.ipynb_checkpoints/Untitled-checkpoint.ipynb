# %%
import matplotlib.pyplot as plt
import random as rnd

# %%
results_comparison = {}

models = ['mp','cp','alns']

model_dict = {'mp':'Mixed-integer programming',
              'cp':'Constraint programming',
              'alns': 'Adaptive LNS'}

titles = ['Minor - 4 note',
          'Minor - 8 note',
          'Minor - 16 note',
          'Major - 4 note',
          'Major - 8 note',
          'Major - 16 note',
          ]

for title in titles:
    for model in models:
        results_comparison[(model_dict[model],title)] = [(i,rnd.randint(1,100)) for i in range(100)]

# %%
results_comparison
# Out:
# {('Mixed-integer programming', 'Minor - 4 note'): [(0, 3),
#   (1, 57),
#   (2, 31),
#   (3, 41),
#   (4, 44),
#   (5, 21),
#   (6, 28),
#   (7, 50),
#   (8, 27),
#   (9, 59),
#   (10, 65),
#   (11, 81),
#   (12, 94),
#   (13, 23),
#   (14, 33),
#   (15, 74),
#   (16, 29),
#   (17, 50),
#   (18, 51),
#   (19, 96),
#   (20, 21),
#   (21, 44),
#   (22, 27),
#   (23, 61),
#   (24, 65),
#   (25, 77),
#   (26, 57),
#   (27, 36),
#   (28, 20),
#   (29, 20),
#   (30, 49),
#   (31, 16),
#   (32, 39),
#   (33, 60),
#   (34, 35),
#   (35, 74),
#   (36, 10),
#   (37, 30),
#   (38, 42),
#   (39, 62),
#   (40, 3),
#   (41, 34),
#   (42, 11),
#   (43, 75),
#   (44, 5),
#   (45, 59),
#   (46, 24),
#   (47, 80),
#   (48, 75),
#   (49, 81),
#   (50, 15),
#   (51, 94),
#   (52, 13),
#   (53, 54),
#   (54, 5),
#   (55, 11),
#   (56, 19),
#   (57, 46),
#   (58, 94),
#   (59, 16),
#   (60, 65),
#   (61, 24),
#   (62, 79),
#   (63, 71),
#   (64, 35),
#   (65, 29),
#   (66, 20),
#   (67, 31),
#   (68, 33),
#   (69, 34),
#   (70, 2),
#   (71, 1),
#   (72, 32),
#   (73, 64),
#   (74, 82),
#   (75, 44),
#   (76, 14),
#   (77, 4),
#   (78, 50),
#   (79, 37),
#   (80, 71),
#   (81, 17),
#   (82, 77),
#   (83, 72),
#   (84, 11),
#   (85, 81),
#   (86, 18),
#   (87, 49),
#   (88, 41),
#   (89, 41),
#   (90, 87),
#   (91, 28),
#   (92, 6),
#   (93, 18),
#   (94, 26),
#   (95, 96),
#   (96, 51),
#   (97, 57),
#   (98, 93),
#   (99, 58)],
#  ('Constraint programming', 'Minor - 4 note'): [(0, 61),
#   (1, 13),
#   (2, 63),
#   (3, 45),
#   (4, 5),
#   (5, 99),
#   (6, 9),
#   (7, 38),
#   (8, 100),
#   (9, 10),
#   (10, 85),
#   (11, 74),
#   (12, 47),
#   (13, 44),
#   (14, 28),
#   (15, 21),
#   (16, 58),
#   (17, 95),
#   (18, 55),
#   (19, 6),
#   (20, 36),
#   (21, 85),
#   (22, 81),
#   (23, 69),
#   (24, 35),
#   (25, 16),
#   (26, 100),
#   (27, 39),
#   (28, 21),
#   (29, 72),
#   (30, 81),
#   (31, 90),
#   (32, 57),
#   (33, 75),
#   (34, 42),
#   (35, 94),
#   (36, 77),
#   (37, 62),
#   (38, 51),
#   (39, 80),
#   (40, 14),
#   (41, 63),
#   (42, 1),
#   (43, 69),
#   (44, 25),
#   (45, 78),
#   (46, 45),
#   (47, 52),
#   (48, 95),
#   (49, 15),
#   (50, 59),
#   (51, 61),
#   (52, 80),
#   (53, 81),
#   (54, 75),
#   (55, 90),
#   (56, 48),
#   (57, 17),
#   (58, 15),
#   (59, 49),
#   (60, 24),
#   (61, 26),
#   (62, 79),
#   (63, 11),
#   (64, 81),
#   (65, 40),
#   (66, 66),
#   (67, 93),
#   (68, 61),
#   (69, 72),
#   (70, 94),
#   (71, 92),
#   (72, 47),
#   (73, 8),
#   (74, 64),
#   (75, 37),
#   (76, 48),
#   (77, 91),
#   (78, 80),
#   (79, 29),
#   (80, 43),
#   (81, 100),
#   (82, 66),
#   (83, 9),
#   (84, 26),
#   (85, 74),
#   (86, 64),
#   (87, 100),
#   (88, 33),
#   (89, 87),
#   (90, 21),
#   (91, 84),
#   (92, 13),
#   (93, 57),
#   (94, 91),
#   (95, 41),
#   (96, 66),
#   (97, 96),
#   (98, 10),
#   (99, 85)],
#  ('Adaptive LNS', 'Minor - 4 note'): [(0, 63),
#   (1, 40),
#   (2, 76),
#   (3, 98),
#   (4, 66),
#   (5, 9),
#   (6, 82),
#   (7, 18),
#   (8, 32),
#   (9, 20),
#   (10, 31),
#   (11, 88),
#   (12, 23),
#   (13, 78),
#   (14, 17),
#   (15, 74),
#   (16, 67),
#   (17, 94),
#   (18, 89),
#   (19, 87),
#   (20, 42),
#   (21, 67),
#   (22, 71),
#   (23, 22),
#   (24, 33),
#   (25, 70),
#   (26, 8),
#   (27, 99),
#   (28, 16),
#   (29, 34),
#   (30, 47),
#   (31, 10),
#   (32, 38),
#   (33, 50),
#   (34, 11),
#   (35, 28),
#   (36, 28),
#   (37, 51),
#   (38, 92),
#   (39, 27),
#   (40, 41),
#   (41, 7),
#   (42, 36),
#   (43, 91),
#   (44, 3),
#   (45, 8),
#   (46, 44),
#   (47, 90),
#   (48, 53),
#   (49, 59),
#   (50, 4),
#   (51, 63),
#   (52, 23),
#   (53, 83),
#   (54, 6),
#   (55, 51),
#   (56, 71),
#   (57, 39),
#   (58, 31),
#   (59, 99),
#   (60, 28),
#   (61, 69),
#   (62, 44),
#   (63, 28),
#   (64, 98),
#   (65, 51),
#   (66, 98),
#   (67, 2),
#   (68, 56),
#   (69, 24),
#   (70, 36),
#   (71, 84),
#   (72, 3),
#   (73, 38),
#   (74, 88),
#   (75, 93),
#   (76, 74),
#   (77, 87),
#   (78, 10),
#   (79, 31),
#   (80, 23),
#   (81, 33),
#   (82, 68),
#   (83, 9),
#   (84, 10),
#   (85, 51),
#   (86, 5),
#   (87, 89),
#   (88, 34),
#   (89, 35),
#   (90, 65),
#   (91, 86),
#   (92, 43),
#   (93, 50),
#   (94, 41),
#   (95, 89),
#   (96, 92),
#   (97, 79),
#   (98, 4),
#   (99, 96)],
#  ('Mixed-integer programming', 'Minor - 8 note'): [(0, 20),
#   (1, 29),
#   (2, 92),
#   (3, 72),
#   (4, 8),
#   (5, 28),
#   (6, 20),
#   (7, 55),
#   (8, 6),
#   (9, 21),
#   (10, 22),
#   (11, 25),
#   (12, 29),
#   (13, 60),
#   (14, 48),
#   (15, 39),
#   (16, 44),
#   (17, 62),
#   (18, 99),
#   (19, 44),
#   (20, 68),
#   (21, 79),
#   (22, 65),
#   (23, 88),
#   (24, 6),
#   (25, 65),
#   (26, 59),
#   (27, 83),
#   (28, 73),
#   (29, 55),
#   (30, 77),
#   (31, 53),
#   (32, 38),
#   (33, 14),
#   (34, 1),
#   (35, 46),
#   (36, 62),
#   (37, 61),
#   (38, 33),
#   (39, 88),
#   (40, 62),
#   (41, 56),
#   (42, 72),
#   (43, 70),
#   (44, 13),
#   (45, 23),
#   (46, 33),
#   (47, 26),
#   (48, 33),
#   (49, 53),
#   (50, 2),
#   (51, 46),
#   (52, 60),
#   (53, 78),
#   (54, 39),
#   (55, 59),
#   (56, 58),
#   (57, 94),
#   (58, 55),
#   (59, 14),
#   (60, 88),
#   (61, 100),
#   (62, 58),
#   (63, 35),
#   (64, 57),
#   (65, 48),
#   (66, 13),
#   (67, 46),
#   (68, 57),
#   (69, 61),
#   (70, 65),
#   (71, 77),
#   (72, 70),
#   (73, 14),
#   (74, 62),
#   (75, 36),
#   (76, 32),
#   (77, 100),
#   (78, 23),
#   (79, 96),
#   (80, 46),
#   (81, 69),
#   (82, 46),
#   (83, 91),
#   (84, 88),
#   (85, 45),
#   (86, 84),
#   (87, 81),
#   (88, 76),
#   (89, 29),
#   (90, 55),
#   (91, 81),
#   (92, 1),
#   (93, 7),
#   (94, 12),
#   (95, 100),
#   (96, 4),
#   (97, 66),
#   (98, 12),
#   (99, 26)],
#  ('Constraint programming', 'Minor - 8 note'): [(0, 11),
#   (1, 80),
#   (2, 67),
#   (3, 1),
#   (4, 89),
#   (5, 52),
#   (6, 69),
#   (7, 44),
#   (8, 89),
#   (9, 50),
#   (10, 52),
#   (11, 49),
#   (12, 82),
#   (13, 59),
#   (14, 59),
#   (15, 64),
#   (16, 63),
#   (17, 64),
#   (18, 79),
#   (19, 96),
#   (20, 99),
#   (21, 89),
#   (22, 20),
#   (23, 29),
#   (24, 92),
#   (25, 64),
#   (26, 51),
#   (27, 67),
#   (28, 54),
#   (29, 54),
#   (30, 77),
#   (31, 52),
#   (32, 15),
#   (33, 63),
#   (34, 47),
#   (35, 57),
#   (36, 17),
#   (37, 48),
#   (38, 94),
#   (39, 20),
#   (40, 85),
#   (41, 4),
#   (42, 73),
#   (43, 92),
#   (44, 41),
#   (45, 22),
#   (46, 50),
#   (47, 69),
#   (48, 84),
#   (49, 20),
#   (50, 83),
#   (51, 58),
#   (52, 74),
#   (53, 9),
#   (54, 91),
#   (55, 2),
#   (56, 75),
#   (57, 72),
#   (58, 12),
#   (59, 27),
#   (60, 52),
#   (61, 63),
#   (62, 47),
#   (63, 22),
#   (64, 72),
#   (65, 50),
#   (66, 9),
#   (67, 18),
#   (68, 3),
#   (69, 95),
#   (70, 56),
#   (71, 14),
#   (72, 57),
#   (73, 71),
#   (74, 37),
#   (75, 6),
#   (76, 61),
#   (77, 59),
#   (78, 94),
#   (79, 28),
#   (80, 97),
#   (81, 79),
#   (82, 61),
#   (83, 64),
#   (84, 10),
#   (85, 47),
#   (86, 41),
#   (87, 81),
#   (88, 94),
#   (89, 24),
#   (90, 87),
#   (91, 18),
#   (92, 70),
#   (93, 3),
#   (94, 65),
#   (95, 19),
#   (96, 5),
#   (97, 35),
#   (98, 45),
#   (99, 60)],
#  ('Adaptive LNS', 'Minor - 8 note'): [(0, 67),
#   (1, 76),
#   (2, 99),
#   (3, 58),
#   (4, 98),
#   (5, 51),
#   (6, 58),
#   (7, 7),
#   (8, 25),
#   (9, 60),
#   (10, 47),
#   (11, 8),
#   (12, 41),
#   (13, 43),
#   (14, 75),
#   (15, 23),
#   (16, 44),
#   (17, 100),
#   (18, 79),
#   (19, 52),
#   (20, 25),
#   (21, 58),
#   (22, 78),
#   (23, 64),
#   (24, 36),
#   (25, 75),
#   (26, 68),
#   (27, 70),
#   (28, 37),
#   (29, 77),
#   (30, 31),
#   (31, 27),
#   (32, 50),
#   (33, 19),
#   (34, 33),
#   (35, 25),
#   (36, 97),
#   (37, 22),
#   (38, 91),
#   (39, 25),
#   (40, 35),
#   (41, 25),
#   (42, 37),
#   (43, 14),
#   (44, 5),
#   (45, 21),
#   (46, 58),
#   (47, 84),
#   (48, 60),
#   (49, 74),
#   (50, 85),
#   (51, 88),
#   (52, 40),
#   (53, 48),
#   (54, 46),
#   (55, 77),
#   (56, 65),
#   (57, 3),
#   (58, 51),
#   (59, 60),
#   (60, 5),
#   (61, 27),
#   (62, 72),
#   (63, 24),
#   (64, 39),
#   (65, 12),
#   (66, 61),
#   (67, 16),
#   (68, 38),
#   (69, 67),
#   (70, 43),
#   (71, 88),
#   (72, 45),
#   (73, 74),
#   (74, 32),
#   (75, 88),
#   (76, 12),
#   (77, 89),
#   (78, 90),
#   (79, 70),
#   (80, 10),
#   (81, 84),
#   (82, 91),
#   (83, 61),
#   (84, 53),
#   (85, 59),
#   (86, 53),
#   (87, 35),
#   (88, 81),
#   (89, 62),
#   (90, 91),
#   (91, 27),
#   (92, 18),
#   (93, 40),
#   (94, 28),
#   (95, 81),
#   (96, 36),
#   (97, 91),
#   (98, 73),
#   (99, 56)],
#  ('Mixed-integer programming', 'Minor - 16 note'): [(0, 33),
#   (1, 25),
#   (2, 58),
#   (3, 17),
#   (4, 52),
#   (5, 84),
#   (6, 65),
#   (7, 35),
#   (8, 77),
#   (9, 30),
#   (10, 10),
#   (11, 90),
#   (12, 72),
#   (13, 36),
#   (14, 43),
#   (15, 11),
#   (16, 1),
#   (17, 86),
#   (18, 56),
#   (19, 58),
#   (20, 65),
#   (21, 83),
#   (22, 9),
#   (23, 25),
#   (24, 84),
#   (25, 98),
#   (26, 46),
#   (27, 33),
#   (28, 34),
#   (29, 83),
#   (30, 64),
#   (31, 87),
#   (32, 36),
#   (33, 55),
#   (34, 36),
#   (35, 42),
#   (36, 3),
#   (37, 39),
#   (38, 86),
#   (39, 65),
#   (40, 87),
#   (41, 30),
#   (42, 45),
#   (43, 35),
#   (44, 9),
#   (45, 14),
#   (46, 97),
#   (47, 90),
#   (48, 93),
#   (49, 39),
#   (50, 21),
#   (51, 44),
#   (52, 50),
#   (53, 63),
#   (54, 81),
#   (55, 21),
#   (56, 43),
#   (57, 3),
#   (58, 11),
#   (59, 87),
#   (60, 42),
#   (61, 57),
#   (62, 20),
#   (63, 36),
#   (64, 88),
#   (65, 88),
#   (66, 65),
#   (67, 3),
#   (68, 57),
#   (69, 100),
#   (70, 98),
#   (71, 69),
#   (72, 28),
#   (73, 8),
#   (74, 5),
#   (75, 68),
#   (76, 30),
#   (77, 26),
#   (78, 76),
#   (79, 25),
#   (80, 16),
#   (81, 18),
#   (82, 54),
#   (83, 98),
#   (84, 33),
#   (85, 13),
#   (86, 66),
#   (87, 60),
#   (88, 72),
#   (89, 89),
#   (90, 97),
#   (91, 69),
#   (92, 37),
#   (93, 53),
#   (94, 28),
#   (95, 46),
#   (96, 54),
#   (97, 72),
#   (98, 3),
#   (99, 56)],
#  ('Constraint programming', 'Minor - 16 note'): [(0, 47),
#   (1, 75),
#   (2, 39),
#   (3, 74),
#   (4, 30),
#   (5, 44),
#   (6, 41),
#   (7, 48),
#   (8, 61),
#   (9, 22),
#   (10, 69),
#   (11, 6),
#   (12, 81),
#   (13, 75),
#   (14, 93),
#   (15, 25),
#   (16, 16),
#   (17, 97),
#   (18, 52),
#   (19, 28),
#   (20, 75),
#   (21, 94),
#   (22, 65),
#   (23, 57),
#   (24, 61),
#   (25, 7),
#   (26, 61),
#   (27, 95),
#   (28, 78),
#   (29, 79),
#   (30, 9),
#   (31, 11),
#   (32, 24),
#   (33, 74),
#   (34, 26),
#   (35, 85),
#   (36, 77),
#   (37, 50),
#   (38, 1),
#   (39, 72),
#   (40, 96),
#   (41, 47),
#   (42, 68),
#   (43, 31),
#   (44, 48),
#   (45, 30),
#   (46, 97),
#   (47, 23),
#   (48, 4),
#   (49, 38),
#   (50, 75),
#   (51, 70),
#   (52, 87),
#   (53, 30),
#   (54, 4),
#   (55, 52),
#   (56, 72),
#   (57, 76),
#   (58, 24),
#   (59, 37),
#   (60, 42),
#   (61, 60),
#   (62, 92),
#   (63, 57),
#   (64, 96),
#   (65, 25),
#   (66, 21),
#   (67, 54),
#   (68, 96),
#   (69, 34),
#   (70, 70),
#   (71, 94),
#   (72, 13),
#   (73, 89),
#   (74, 40),
#   (75, 66),
#   (76, 99),
#   (77, 90),
#   (78, 3),
#   (79, 20),
#   (80, 43),
#   (81, 38),
#   (82, 99),
#   (83, 80),
#   (84, 12),
#   (85, 98),
#   (86, 63),
#   (87, 70),
#   (88, 58),
#   (89, 31),
#   (90, 91),
#   (91, 71),
#   (92, 7),
#   (93, 24),
#   (94, 79),
#   (95, 32),
#   (96, 53),
#   (97, 41),
#   (98, 47),
#   (99, 3)],
#  ('Adaptive LNS', 'Minor - 16 note'): [(0, 96),
#   (1, 58),
#   (2, 13),
#   (3, 57),
#   (4, 48),
#   (5, 71),
#   (6, 27),
#   (7, 25),
#   (8, 65),
#   (9, 94),
#   (10, 74),
#   (11, 29),
#   (12, 61),
#   (13, 67),
#   (14, 66),
#   (15, 38),
#   (16, 71),
#   (17, 16),
#   (18, 80),
#   (19, 39),
#   (20, 3),
#   (21, 93),
#   (22, 99),
#   (23, 13),
#   (24, 77),
#   (25, 6),
#   (26, 77),
#   (27, 1),
#   (28, 74),
#   (29, 22),
#   (30, 39),
#   (31, 56),
#   (32, 8),
#   (33, 52),
#   (34, 9),
#   (35, 71),
#   (36, 19),
#   (37, 94),
#   (38, 95),
#   (39, 79),
#   (40, 10),
#   (41, 74),
#   (42, 83),
#   (43, 54),
#   (44, 79),
#   (45, 3),
#   (46, 7),
#   (47, 21),
#   (48, 95),
#   (49, 41),
#   (50, 5),
#   (51, 92),
#   (52, 37),
#   (53, 47),
#   (54, 68),
#   (55, 65),
#   (56, 94),
#   (57, 90),
#   (58, 42),
#   (59, 90),
#   (60, 24),
#   (61, 14),
#   (62, 58),
#   (63, 76),
#   (64, 25),
#   (65, 87),
#   (66, 37),
#   (67, 82),
#   (68, 15),
#   (69, 27),
#   (70, 50),
#   (71, 81),
#   (72, 47),
#   (73, 37),
#   (74, 44),
#   (75, 94),
#   (76, 54),
#   (77, 40),
#   (78, 63),
#   (79, 69),
#   (80, 53),
#   (81, 90),
#   (82, 84),
#   (83, 42),
#   (84, 39),
#   (85, 7),
#   (86, 43),
#   (87, 70),
#   (88, 15),
#   (89, 8),
#   (90, 1),
#   (91, 70),
#   (92, 16),
#   (93, 67),
#   (94, 34),
#   (95, 83),
#   (96, 95),
#   (97, 84),
#   (98, 85),
#   (99, 71)],
#  ('Mixed-integer programming', 'Major - 4 note'): [(0, 69),
#   (1, 35),
#   (2, 97),
#   (3, 33),
#   (4, 12),
#   (5, 87),
#   (6, 56),
#   (7, 84),
#   (8, 48),
#   (9, 7),
#   (10, 24),
#   (11, 71),
#   (12, 96),
#   (13, 32),
#   (14, 14),
#   (15, 95),
#   (16, 71),
#   (17, 5),
#   (18, 69),
#   (19, 72),
#   (20, 44),
#   (21, 26),
#   (22, 55),
#   (23, 56),
#   (24, 92),
#   (25, 23),
#   (26, 54),
#   (27, 49),
#   (28, 41),
#   (29, 4),
#   (30, 76),
#   (31, 33),
#   (32, 29),
#   (33, 10),
#   (34, 32),
#   (35, 76),
#   (36, 71),
#   (37, 81),
#   (38, 7),
#   (39, 42),
#   (40, 56),
#   (41, 31),
#   (42, 76),
#   (43, 5),
#   (44, 7),
#   (45, 78),
#   (46, 86),
#   (47, 20),
#   (48, 23),
#   (49, 22),
#   (50, 30),
#   (51, 85),
#   (52, 24),
#   (53, 40),
#   (54, 97),
#   (55, 49),
#   (56, 17),
#   (57, 63),
#   (58, 25),
#   (59, 80),
#   (60, 36),
#   (61, 13),
#   (62, 4),
#   (63, 99),
#   (64, 47),
#   (65, 36),
#   (66, 36),
#   (67, 94),
#   (68, 84),
#   (69, 44),
#   (70, 57),
#   (71, 3),
#   (72, 1),
#   (73, 20),
#   (74, 52),
#   (75, 17),
#   (76, 22),
#   (77, 21),
#   (78, 91),
#   (79, 56),
#   (80, 23),
#   (81, 17),
#   (82, 53),
#   (83, 72),
#   (84, 35),
#   (85, 29),
#   (86, 87),
#   (87, 15),
#   (88, 43),
#   (89, 96),
#   (90, 68),
#   (91, 14),
#   (92, 58),
#   (93, 85),
#   (94, 91),
#   (95, 74),
#   (96, 89),
#   (97, 51),
#   (98, 40),
#   (99, 49)],
#  ('Constraint programming', 'Major - 4 note'): [(0, 81),
#   (1, 33),
#   (2, 16),
#   (3, 43),
#   (4, 10),
#   (5, 54),
#   (6, 99),
#   (7, 53),
#   (8, 86),
#   (9, 57),
#   (10, 34),
#   (11, 31),
#   (12, 54),
#   (13, 47),
#   (14, 95),
#   (15, 37),
#   (16, 88),
#   (17, 66),
#   (18, 23),
#   (19, 91),
#   (20, 64),
#   (21, 14),
#   (22, 50),
#   (23, 26),
#   (24, 22),
#   (25, 7),
#   (26, 2),
#   (27, 77),
#   (28, 8),
#   (29, 61),
#   (30, 83),
#   (31, 50),
#   (32, 63),
#   (33, 32),
#   (34, 35),
#   (35, 56),
#   (36, 39),
#   (37, 88),
#   (38, 95),
#   (39, 62),
#   (40, 2),
#   (41, 46),
#   (42, 69),
#   (43, 40),
#   (44, 74),
#   (45, 15),
#   (46, 62),
#   (47, 45),
#   (48, 85),
#   (49, 7),
#   (50, 50),
#   (51, 54),
#   (52, 17),
#   (53, 69),
#   (54, 48),
#   (55, 15),
#   (56, 32),
#   (57, 63),
#   (58, 19),
#   (59, 67),
#   (60, 96),
#   (61, 68),
#   (62, 42),
#   (63, 43),
#   (64, 29),
#   (65, 24),
#   (66, 50),
#   (67, 61),
#   (68, 66),
#   (69, 90),
#   (70, 1),
#   (71, 71),
#   (72, 64),
#   (73, 90),
#   (74, 79),
#   (75, 84),
#   (76, 85),
#   (77, 11),
#   (78, 30),
#   (79, 69),
#   (80, 16),
#   (81, 43),
#   (82, 100),
#   (83, 34),
#   (84, 86),
#   (85, 38),
#   (86, 82),
#   (87, 41),
#   (88, 23),
#   (89, 57),
#   (90, 15),
#   (91, 86),
#   (92, 5),
#   (93, 49),
#   (94, 81),
#   (95, 76),
#   (96, 75),
#   (97, 10),
#   (98, 12),
#   (99, 80)],
#  ('Adaptive LNS', 'Major - 4 note'): [(0, 93),
#   (1, 79),
#   (2, 5),
#   (3, 55),
#   (4, 82),
#   (5, 22),
#   (6, 25),
#   (7, 81),
#   (8, 43),
#   (9, 74),
#   (10, 88),
#   (11, 32),
#   (12, 27),
#   (13, 26),
#   (14, 10),
#   (15, 53),
#   (16, 14),
#   (17, 46),
#   (18, 66),
#   (19, 81),
#   (20, 43),
#   (21, 12),
#   (22, 50),
#   (23, 71),
#   (24, 85),
#   (25, 50),
#   (26, 9),
#   (27, 86),
#   (28, 51),
#   (29, 90),
#   (30, 82),
#   (31, 100),
#   (32, 66),
#   (33, 50),
#   (34, 68),
#   (35, 56),
#   (36, 88),
#   (37, 92),
#   (38, 4),
#   (39, 66),
#   (40, 77),
#   (41, 46),
#   (42, 97),
#   (43, 51),
#   (44, 26),
#   (45, 47),
#   (46, 13),
#   (47, 43),
#   (48, 56),
#   (49, 84),
#   (50, 84),
#   (51, 95),
#   (52, 28),
#   (53, 46),
#   (54, 91),
#   (55, 4),
#   (56, 49),
#   (57, 10),
#   (58, 8),
#   (59, 67),
#   (60, 20),
#   (61, 29),
#   (62, 81),
#   (63, 7),
#   (64, 12),
#   (65, 24),
#   (66, 90),
#   (67, 38),
#   (68, 2),
#   (69, 2),
#   (70, 24),
#   (71, 70),
#   (72, 62),
#   (73, 84),
#   (74, 64),
#   (75, 5),
#   (76, 38),
#   (77, 9),
#   (78, 51),
#   (79, 30),
#   (80, 80),
#   (81, 66),
#   (82, 50),
#   (83, 42),
#   (84, 24),
#   (85, 3),
#   (86, 66),
#   (87, 92),
#   (88, 56),
#   (89, 95),
#   (90, 4),
#   (91, 25),
#   (92, 66),
#   (93, 58),
#   (94, 99),
#   (95, 49),
#   (96, 28),
#   (97, 91),
#   (98, 60),
#   (99, 70)],
#  ('Mixed-integer programming', 'Major - 8 note'): [(0, 37),
#   (1, 13),
#   (2, 45),
#   (3, 81),
#   (4, 49),
#   (5, 75),
#   (6, 65),
#   (7, 32),
#   (8, 10),
#   (9, 1),
#   (10, 19),
#   (11, 98),
#   (12, 53),
#   (13, 57),
#   (14, 4),
#   (15, 96),
#   (16, 12),
#   (17, 60),
#   (18, 69),
#   (19, 8),
#   (20, 61),
#   (21, 4),
#   (22, 94),
#   (23, 66),
#   (24, 52),
#   (25, 76),
#   (26, 26),
#   (27, 13),
#   (28, 37),
#   (29, 17),
#   (30, 18),
#   (31, 66),
#   (32, 73),
#   (33, 18),
#   (34, 86),
#   (35, 97),
#   (36, 80),
#   (37, 2),
#   (38, 42),
#   (39, 77),
#   (40, 95),
#   (41, 18),
#   (42, 23),
#   (43, 27),
#   (44, 7),
#   (45, 86),
#   (46, 36),
#   (47, 3),
#   (48, 47),
#   (49, 77),
#   (50, 68),
#   (51, 2),
#   (52, 2),
#   (53, 68),
#   (54, 71),
#   (55, 28),
#   (56, 9),
#   (57, 16),
#   (58, 73),
#   (59, 21),
#   (60, 1),
#   (61, 15),
#   (62, 38),
#   (63, 15),
#   (64, 12),
#   (65, 9),
#   (66, 38),
#   (67, 26),
#   (68, 95),
#   (69, 8),
#   (70, 46),
#   (71, 45),
#   (72, 17),
#   (73, 40),
#   (74, 86),
#   (75, 32),
#   (76, 20),
#   (77, 34),
#   (78, 53),
#   (79, 58),
#   (80, 65),
#   (81, 36),
#   (82, 62),
#   (83, 79),
#   (84, 76),
#   (85, 98),
#   (86, 96),
#   (87, 90),
#   (88, 62),
#   (89, 66),
#   (90, 94),
#   (91, 23),
#   (92, 33),
#   (93, 81),
#   (94, 45),
#   (95, 77),
#   (96, 95),
#   (97, 42),
#   (98, 59),
#   (99, 33)],
#  ('Constraint programming', 'Major - 8 note'): [(0, 99),
#   (1, 3),
#   (2, 40),
#   (3, 29),
#   (4, 41),
#   (5, 44),
#   (6, 75),
#   (7, 35),
#   (8, 39),
#   (9, 70),
#   (10, 15),
#   (11, 68),
#   (12, 23),
#   (13, 10),
#   (14, 53),
#   (15, 49),
#   (16, 82),
#   (17, 91),
#   (18, 43),
#   (19, 49),
#   (20, 12),
#   (21, 25),
#   (22, 78),
#   (23, 75),
#   (24, 29),
#   (25, 10),
#   (26, 85),
#   (27, 17),
#   (28, 32),
#   (29, 30),
#   (30, 9),
#   (31, 30),
#   (32, 90),
#   (33, 23),
#   (34, 38),
#   (35, 59),
#   (36, 36),
#   (37, 92),
#   (38, 37),
#   (39, 20),
#   (40, 6),
#   (41, 2),
#   (42, 51),
#   (43, 39),
#   (44, 55),
#   (45, 29),
#   (46, 85),
#   (47, 61),
#   (48, 36),
#   (49, 60),
#   (50, 9),
#   (51, 14),
#   (52, 48),
#   (53, 34),
#   (54, 100),
#   (55, 44),
#   (56, 27),
#   (57, 36),
#   (58, 37),
#   (59, 45),
#   (60, 37),
#   (61, 70),
#   (62, 44),
#   (63, 29),
#   (64, 23),
#   (65, 14),
#   (66, 16),
#   (67, 56),
#   (68, 97),
#   (69, 31),
#   (70, 67),
#   (71, 71),
#   (72, 68),
#   (73, 49),
#   (74, 11),
#   (75, 94),
#   (76, 74),
#   (77, 83),
#   (78, 17),
#   (79, 85),
#   (80, 70),
#   (81, 8),
#   (82, 85),
#   (83, 23),
#   (84, 77),
#   (85, 12),
#   (86, 30),
#   (87, 4),
#   (88, 44),
#   (89, 28),
#   (90, 19),
#   (91, 6),
#   (92, 5),
#   (93, 65),
#   (94, 50),
#   (95, 6),
#   (96, 87),
#   (97, 32),
#   (98, 70),
#   (99, 86)],
#  ('Adaptive LNS', 'Major - 8 note'): [(0, 73),
#   (1, 3),
#   (2, 70),
#   (3, 49),
#   (4, 5),
#   (5, 66),
#   (6, 47),
#   (7, 11),
#   (8, 91),
#   (9, 82),
#   (10, 36),
#   (11, 52),
#   (12, 86),
#   (13, 1),
#   (14, 50),
#   (15, 81),
#   (16, 25),
#   (17, 47),
#   (18, 69),
#   (19, 75),
#   (20, 8),
#   (21, 57),
#   (22, 82),
#   (23, 22),
#   (24, 43),
#   (25, 40),
#   (26, 59),
#   (27, 69),
#   (28, 85),
#   (29, 9),
#   (30, 12),
#   (31, 1),
#   (32, 70),
#   (33, 51),
#   (34, 94),
#   (35, 48),
#   (36, 23),
#   (37, 23),
#   (38, 72),
#   (39, 63),
#   (40, 36),
#   (41, 21),
#   (42, 74),
#   (43, 51),
#   (44, 48),
#   (45, 65),
#   (46, 29),
#   (47, 59),
#   (48, 27),
#   (49, 67),
#   (50, 79),
#   (51, 59),
#   (52, 15),
#   (53, 63),
#   (54, 23),
#   (55, 6),
#   (56, 50),
#   (57, 86),
#   (58, 28),
#   (59, 2),
#   (60, 41),
#   (61, 76),
#   (62, 54),
#   (63, 68),
#   (64, 41),
#   (65, 15),
#   (66, 65),
#   (67, 4),
#   (68, 59),
#   (69, 68),
#   (70, 61),
#   (71, 41),
#   (72, 78),
#   (73, 45),
#   (74, 35),
#   (75, 41),
#   (76, 69),
#   (77, 92),
#   (78, 4),
#   (79, 61),
#   (80, 66),
#   (81, 96),
#   (82, 39),
#   (83, 95),
#   (84, 51),
#   (85, 65),
#   (86, 71),
#   (87, 19),
#   (88, 41),
#   (89, 11),
#   (90, 40),
#   (91, 92),
#   (92, 100),
#   (93, 99),
#   (94, 92),
#   (95, 68),
#   (96, 59),
#   (97, 90),
#   (98, 22),
#   (99, 30)],
#  ('Mixed-integer programming', 'Major - 16 note'): [(0, 23),
#   (1, 76),
#   (2, 59),
#   (3, 51),
#   (4, 96),
#   (5, 69),
#   (6, 65),
#   (7, 98),
#   (8, 60),
#   (9, 48),
#   (10, 71),
#   (11, 82),
#   (12, 6),
#   (13, 64),
#   (14, 16),
#   (15, 86),
#   (16, 1),
#   (17, 67),
#   (18, 79),
#   (19, 1),
#   (20, 46),
#   (21, 13),
#   (22, 6),
#   (23, 16),
#   (24, 77),
#   (25, 42),
#   (26, 53),
#   (27, 68),
#   (28, 44),
#   (29, 99),
#   (30, 73),
#   (31, 71),
#   (32, 61),
#   (33, 91),
#   (34, 34),
#   (35, 48),
#   (36, 29),
#   (37, 83),
#   (38, 31),
#   (39, 96),
#   (40, 79),
#   (41, 47),
#   (42, 49),
#   (43, 16),
#   (44, 48),
#   (45, 20),
#   (46, 54),
#   (47, 60),
#   (48, 15),
#   (49, 29),
#   (50, 100),
#   (51, 99),
#   (52, 83),
#   (53, 62),
#   (54, 89),
#   (55, 21),
#   (56, 68),
#   (57, 37),
#   (58, 75),
#   (59, 14),
#   (60, 28),
#   (61, 57),
#   (62, 58),
#   (63, 30),
#   (64, 6),
#   (65, 11),
#   (66, 27),
#   (67, 68),
#   (68, 8),
#   (69, 17),
#   (70, 11),
#   (71, 49),
#   (72, 36),
#   (73, 53),
#   (74, 10),
#   (75, 32),
#   (76, 55),
#   (77, 44),
#   (78, 37),
#   (79, 13),
#   (80, 10),
#   (81, 75),
#   (82, 62),
#   (83, 18),
#   (84, 58),
#   (85, 97),
#   (86, 6),
#   (87, 46),
#   (88, 36),
#   (89, 62),
#   (90, 11),
#   (91, 39),
#   (92, 83),
#   (93, 93),
#   (94, 83),
#   (95, 65),
#   (96, 37),
#   (97, 74),
#   (98, 59),
#   (99, 32)],
#  ('Constraint programming', 'Major - 16 note'): [(0, 78),
#   (1, 57),
#   (2, 67),
#   (3, 27),
#   (4, 62),
#   (5, 15),
#   (6, 78),
#   (7, 8),
#   (8, 32),
#   (9, 98),
#   (10, 17),
#   (11, 71),
#   (12, 1),
#   (13, 85),
#   (14, 61),
#   (15, 58),
#   (16, 93),
#   (17, 62),
#   (18, 29),
#   (19, 54),
#   (20, 87),
#   (21, 25),
#   (22, 68),
#   (23, 49),
#   (24, 19),
#   (25, 93),
#   (26, 41),
#   (27, 90),
#   (28, 59),
#   (29, 96),
#   (30, 86),
#   (31, 90),
#   (32, 68),
#   (33, 9),
#   (34, 46),
#   (35, 37),
#   (36, 22),
#   (37, 32),
#   (38, 87),
#   (39, 85),
#   (40, 67),
#   (41, 51),
#   (42, 14),
#   (43, 48),
#   (44, 67),
#   (45, 79),
#   (46, 40),
#   (47, 28),
#   (48, 49),
#   (49, 41),
#   (50, 53),
#   (51, 62),
#   (52, 56),
#   (53, 81),
#   (54, 91),
#   (55, 60),
#   (56, 93),
#   (57, 61),
#   (58, 81),
#   (59, 43),
#   (60, 61),
#   (61, 48),
#   (62, 43),
#   (63, 97),
#   (64, 72),
#   (65, 2),
#   (66, 50),
#   (67, 23),
#   (68, 96),
#   (69, 29),
#   (70, 10),
#   (71, 54),
#   (72, 34),
#   (73, 82),
#   (74, 43),
#   (75, 3),
#   (76, 75),
#   (77, 63),
#   (78, 56),
#   (79, 5),
#   (80, 64),
#   (81, 74),
#   (82, 23),
#   (83, 10),
#   (84, 28),
#   (85, 47),
#   (86, 7),
#   (87, 38),
#   (88, 7),
#   (89, 33),
#   (90, 74),
#   (91, 27),
#   (92, 94),
#   (93, 99),
#   (94, 7),
#   (95, 1),
#   (96, 85),
#   (97, 76),
#   (98, 10),
#   (99, 38)],
#  ('Adaptive LNS', 'Major - 16 note'): [(0, 67),
#   (1, 20),
#   (2, 92),
#   (3, 83),
#   (4, 14),
#   (5, 35),
#   (6, 11),
#   (7, 80),
#   (8, 99),
#   (9, 53),
#   (10, 95),
#   (11, 12),
#   (12, 84),
#   (13, 31),
#   (14, 28),
#   (15, 99),
#   (16, 51),
#   (17, 92),
#   (18, 90),
#   (19, 64),
#   (20, 46),
#   (21, 69),
#   (22, 27),
#   (23, 55),
#   (24, 12),
#   (25, 72),
#   (26, 7),
#   (27, 14),
#   (28, 81),
#   (29, 22),
#   (30, 94),
#   (31, 7),
#   (32, 10),
#   (33, 82),
#   (34, 27),
#   (35, 69),
#   (36, 33),
#   (37, 91),
#   (38, 27),
#   (39, 75),
#   (40, 29),
#   (41, 35),
#   (42, 60),
#   (43, 90),
#   (44, 14),
#   (45, 71),
#   (46, 39),
#   (47, 51),
#   (48, 89),
#   (49, 78),
#   (50, 59),
#   (51, 33),
#   (52, 32),
#   (53, 45),
#   (54, 59),
#   (55, 78),
#   (56, 98),
#   (57, 60),
#   (58, 37),
#   (59, 14),
#   (60, 45),
#   (61, 18),
#   (62, 21),
#   (63, 84),
#   (64, 69),
#   (65, 30),
#   (66, 56),
#   (67, 49),
#   (68, 63),
#   (69, 67),
#   (70, 58),
#   (71, 36),
#   (72, 34),
#   (73, 43),
#   (74, 18),
#   (75, 33),
#   (76, 17),
#   (77, 27),
#   (78, 73),
#   (79, 18),
#   (80, 77),
#   (81, 49),
#   (82, 62),
#   (83, 41),
#   (84, 41),
#   (85, 85),
#   (86, 71),
#   (87, 88),
#   (88, 61),
#   (89, 56),
#   (90, 8),
#   (91, 74),
#   (92, 84),
#   (93, 32),
#   (94, 17),
#   (95, 71),
#   (96, 56),
#   (97, 97),
#   (98, 4),
#   (99, 49)]}

# %%
# plot the results
fig, axs = plt.subplots(3,2,figsize = (15,10))

for ax in axs.flat:
    ax.set(xlabel='x-label', ylabel='y-label')

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

for i in range(3):
    axs[i,0].set_ylabel("Objective Value", fontsize=8)
    
for j in range(2):
    axs[2,j].set_xlabel("Time", fontsize=8)
    
i = 0
j = 0
title = titles[0]
axs[i,j].set_title(title, fontsize=8)

for result in results_comparison.keys():
    # set the index for the subplot to draw in
    if result[1] != title and i < 2:
        axs[i,j].legend()
        print(title,i,j)
        i += 1
        title = result[1]
        axs[i,j].set_title(title, fontsize=8)
    elif result[1] != title and i == 2:
        axs[i,j].legend()
        print(title,i,j)
        i = 0
        j += 1
        title = result[1]
        axs[i,j].set_title(title, fontsize=8)
       
    # create the x-s and y-s
    time = []
    obj_val = []
    for data in results_comparison[result]:
        time.append(data[0])
        obj_val.append(data[1])
    axs[i,j].plot(time, obj_val, label = result[0])
# Out:
# Minor - 4 note 0 0
# Minor - 8 note 1 0
# Minor - 16 note 2 0
# Minor - 16 note 0 1
# Major - 4 note 1 1
# Major - 8 note 2 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_36428\2843094040.py in <module>
#      33         i = 0
#      34         j += 1
# ---> 35         axs[i,j].set_title(title, fontsize=8)
#      36
#      37     # create the x-s and y-s
#
# IndexError: index 2 is out of bounds for axis 1 with size 2
